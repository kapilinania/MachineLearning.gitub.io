# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#here we find what is primum 15 and 55
import numpy as np
import pandas as pd
import seaborn as sns

# %%
import matplotlib.pyplot as plt
x=df['age']
y=df['primum']

# %%
# Create a scatter plot
plt.scatter(x, y, label='Data Points', color='blue', marker='o')

# Add labels and a title
plt.xlabel('X-axis Age')
plt.ylabel('Y-axis Prmimum')
plt.title('Scatter Plot Example')

# Add a legend (if needed)
plt.legend()

# Show the plot
plt.show()

# %%
from sklearn import linear_model

# %%
#visualize the data
sns.lmplot(x='age',y='primum',data=df)

# %%
reg=linear_model.LinearRegression()

# %%
#here we are fit the value
reg.fit(df[['age']],df[['primum']])
# Out:
# LinearRegression()

# %%
#here we are predict the values 15 year
reg.predict([[15]])
#15 year ko primum nhi fill karna hai
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[0.]])

# %%
reg.predict([[50]])
# here i am predicct 50 year valuea
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[70000.]])

# %%
#  y=mx+c
reg.coef_
# Out:
# array([[2000.]])

# %%
reg.intercept_
# Out:
# array([-30000.])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
 # y= mx+x
# =2000*50+(-30000)
# Calculate 2000 * 50:
# 2000 * 50 = 100,000

# Add the result to -30000:
# 100,000 + (-30,000) = 70,000
